# %%
from scipy.io import arff
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
data, meta = arff.loadarff('./dataset/FordA_TRAIN.arff')
df = pd.DataFrame(data)

data, meta = arff.loadarff('./dataset/FordA_TEST.arff')
df1 = pd.DataFrame(data)
df
# Out:
#           att1      att2      att3      att4      att5      att6      att7  \
# 0    -0.797172 -0.664392 -0.373015  0.040815  0.526936  0.984288  1.353120
# 1     0.804855  0.634629  0.373474  0.038343 -0.340988 -0.740860 -1.109667
# 2     0.727985  0.111284 -0.499124 -1.068629 -1.578351 -1.990534 -2.302031
# 3    -0.234439 -0.502157 -0.732488 -0.946128 -1.139739 -1.323336 -1.490243
# 4    -0.171328 -0.062285  0.235829  0.710396  1.239969  1.649823  1.876321
# ...        ...       ...       ...       ...       ...       ...       ...
# 3596  0.196022 -0.070102 -0.336226 -0.516799 -0.555282 -0.442793 -0.221369
# 3597  0.041994  0.422255  0.740529  0.975426  1.109891  1.137270  1.058349
# 3598 -0.570054 -0.333165 -0.293519 -0.425344 -0.590869 -0.615648 -0.348033
# 3599  2.006732  2.079150  2.022036  1.867560  1.648112  1.379446  1.093717
# 3600 -0.125241 -0.325363 -0.488237 -0.599045 -0.651111 -0.647106 -0.595040
#
#           att8      att9     att10  ...    att492    att493    att494  \
# 0     1.578108  1.659251  1.640809  ...  0.722417  0.362068  0.092083
# 1    -1.395357 -1.570192 -1.619951  ...  0.049213 -0.258138 -0.510583
# 2    -2.503403 -2.585211 -2.550600  ...  0.463685  0.507735  0.517174
# 3    -1.607077 -1.620430 -1.506933  ... -0.929437 -0.922761 -0.929437
# 4     1.865535  1.703751  1.466467  ...  0.725496  0.697453  0.731967
# ...        ...       ...       ...  ...       ...       ...       ...
# 3596  0.025217  0.233320  0.350545  ...  1.129082  0.528158 -0.039020
# 3597  0.894955  0.671224  0.421544  ... -0.392667 -0.333749 -0.316543
# 3598  0.275412  1.153586  2.035725  ...  0.579700  0.157463 -0.353980
# 3599  0.784057  0.434150  0.029284  ...  1.148971  0.928088  0.634953
# 3600 -0.502922 -0.388109 -0.259946  ...  0.157920  0.288753  0.384876
#
#         att495    att496    att497    att498    att499    att500  target
# 0    -0.081268 -0.212573 -0.391456 -0.664392 -1.073796 -1.564343   b'-1'
# 1    -0.683647 -0.773817 -0.785255 -0.714885 -0.560443 -0.319086    b'1'
# 2     0.504588  0.476270  0.438513  0.394463  0.339400  0.255391   b'-1'
# 3    -0.909409 -0.835970 -0.695768 -0.478790 -0.188707  0.119736   b'-1'
# 4     0.808545  0.839823  0.733046  0.437520 -0.026585 -0.602213   b'-1'
# ...        ...       ...       ...       ...       ...       ...     ...
# 3596 -0.573043 -1.061479 -1.514392 -1.934743 -2.316612 -2.603753   b'-1'
# 3597 -0.340299 -0.392876 -0.450805 -0.482609 -0.467769 -0.393755    b'1'
# 3598 -0.885246 -1.314421 -1.512655 -1.393714 -0.942733 -0.270722   b'-1'
# 3599  0.311682 -0.007376 -0.270543 -0.432145 -0.441231 -0.280709    b'1'
# 3600  0.451628  0.497019  0.527725  0.555761  0.574451  0.573116   b'-1'
#
# [3601 rows x 501 columns]

# %%
df.describe()
# Out:
#               att1         att2         att3         att4         att5  \
# count  3601.000000  3601.000000  3601.000000  3601.000000  3601.000000
# mean     -0.016708    -0.015270    -0.013605    -0.011943    -0.009966
# std       1.058455     1.051904     1.044560     1.042573     1.046933
# min      -3.933454    -3.656912    -3.479467    -3.595350    -3.773891
# 25%      -0.685693    -0.699526    -0.688302    -0.709732    -0.694991
# 50%      -0.007573    -0.003044    -0.003066     0.008598     0.001042
# 75%       0.660360     0.674898     0.683698     0.679474     0.697530
# max       3.503936     3.369278     3.498286     3.493830     3.293318
#
#               att6         att7         att8         att9        att10  ...  \
# count  3601.000000  3601.000000  3601.000000  3601.000000  3601.000000  ...
# mean     -0.007062    -0.003495     0.000568     0.005354     0.010032  ...
# std       1.052829     1.055439     1.054305     1.050424     1.044120  ...
# min      -3.914729    -3.855301    -4.497360    -4.552591    -4.000282  ...
# 25%      -0.691035    -0.690316    -0.701244    -0.675094    -0.687749  ...
# 50%       0.000280    -0.011988    -0.026672    -0.002031     0.010602  ...
# 75%       0.688802     0.721442     0.705021     0.692256     0.689118  ...
# max       3.605585     3.895870     3.741035     3.630933     3.579176  ...
#
#             att491       att492       att493       att494       att495  \
# count  3601.000000  3601.000000  3601.000000  3601.000000  3601.000000
# mean      0.008724     0.006895     0.004053     0.000929    -0.001922
# std       1.037718     1.040632     1.040826     1.036657     1.028358
# min      -4.402103    -4.073011    -4.014450    -3.817036    -3.574256
# 25%      -0.664482    -0.690143    -0.688232    -0.677701    -0.674282
# 50%      -0.001031     0.012348     0.003914     0.005957    -0.002728
# 75%       0.696860     0.714817     0.707357     0.692837     0.666434
# max       3.971919     3.522197     3.842693     3.916653     3.670118
#
#             att496       att497       att498       att499       att500
# count  3601.000000  3601.000000  3601.000000  3601.000000  3601.000000
# mean     -0.003369    -0.003237    -0.001820     0.000031     0.001395
# std       1.018719     1.011871     1.012367     1.020914     1.032490
# min      -3.746353    -3.680805    -3.904569    -4.221550    -4.076032
# 25%      -0.655946    -0.657258    -0.664392    -0.659578    -0.675838
# 50%      -0.010841    -0.008002    -0.004802    -0.013723    -0.003186
# 75%       0.668463     0.671536     0.677346     0.684048     0.682921
# max       3.567879     3.471847     3.798079     3.863325     4.349744
#
# [8 rows x 500 columns]

# %%
# 상관 행렬 계산
corr = df.corr()

# 히트맵 그리기
plt.figure(figsize=(10, 8))
sns.heatmap(corr, cmap='coolwarm', vmin=-1, vmax=1, annot=False)
plt.title('Correlation Matrix')
plt.show()

# 상관 관계 분석 및 시각화 - 히트맵을 통해 근처 센서간의 연관성 높다는 것 파악가능하다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, StandardScaler 
from sklearn.metrics import roc_curve, auc
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, GRU, Embedding, LSTM, Flatten, MaxPooling1D, BatchNormalization, Dropout, TimeDistributed, Conv1D, Conv2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau


from time import time

def draw_roc_keras(model, xt, yt):
    predictions = model.predict(xt)
    if predictions.shape[1] == 2:
        predictions = predictions[:, 1] 

    fpr, tpr, thr = roc_curve(yt, predictions)
    roc_auc = auc(fpr, tpr)
    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()
    return predictions

# %%
from scipy.io.arff import loadarff

train_path="./dataset/FordA_TRAIN.arff"
test_path="./dataset/FordA_TEST.arff"

def read_ariff(path):
    raw_data, meta =loadarff(path)
    cols=[x for x in meta]
    data2d=np.zeros([raw_data.shape[0],len(cols)])
    for i,col in zip(range(len(cols)),cols):
        data2d[:,i]=raw_data[col]
    print(data2d.shape)
    return data2d

data2d=read_ariff(train_path)
test2d=read_ariff(test_path)
print(data2d.shape, test2d.shape)
# Out:
# (3601, 501)
# (1320, 501)
# (3601, 501) (1320, 501)

# %%
# 첫 번째 subplot: t1 시간대 (data2d[1, :])
plt.subplot(2, 1, 1)  # 2행 1열 중 첫 번째 subplot
plt.plot(data2d[1, :], linestyle='-', color='b')
plt.xlabel('센서')
plt.ylabel('값')
plt.title('t1 시간대 각 센서에 따른 값(정상)')
plt.grid(True)  # 그리드 추가

# 두 번째 subplot: t2 시간대 (data2d[2, :])
plt.subplot(2, 1, 2)  # 2행 1열 중 두 번째 subplot
plt.plot(data2d[2, :],  linestyle='-', color='r')
plt.xlabel('센서')
plt.ylabel('값')
plt.title('t2 시간대 각 센서에 따른 값(불량)')
plt.grid(True)  # 그리드 추가

# 전체 그래프 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

plt.tight_layout()  # 레이아웃 조정
plt.show()

# %%
failed=data2d[data2d[:,-1]==1]
not_failed=data2d[data2d[:,-1]==-1]
print(failed.shape, not_failed.shape)

train2d=np.concatenate((failed[:int(0.8*failed.shape[0])],
                       not_failed[:int(0.8*failed.shape[0])]),
                       axis=0)

val2d=np.concatenate((failed[int(0.8*failed.shape[0]):],
                       not_failed[int(0.8*failed.shape[0]):]),
                       axis=0)

np.random.shuffle(train2d)
np.random.shuffle(val2d)

print(train2d.shape, val2d.shape)
# Out:
# (1755, 501) (1846, 501)
# (2808, 501) (793, 501)

# %%
def make3d(data):
    df=data.copy()
    x,y=df.shape
    data3d=np.zeros([x,y-1,2])
    for i in range(x):
        data3d[i,:,0]=df[i][:-1].T
        data3d[i,:,1]=np.full((y-1),df[i][-1])
    return data3d

train3d=make3d(train2d)
val3d  =make3d(val2d)
test3d =make3d(test2d)
print(train3d.shape, val3d.shape, test3d.shape)
# Out:
# (2808, 500, 2) (793, 500, 2) (1320, 500, 2)

# %% [markdown]
# Scaling the data

# %%
def scale_d(data):
    df=data.copy()
    df_scaled=np.zeros(df.shape)
    scaler = MinMaxScaler(feature_range=(-1, 1))
    stder = StandardScaler()
    # scaler = scaler.fit(df[0])
    for i in range(df.shape[0]):
        df_scaled[i,:,0]=stder.fit_transform(
                                         df[i,:,0].reshape((df.shape[1], 1))
                                         ).reshape((df.shape[1]))

        df_scaled[i,:,1]=df[i,:,1]
    return df_scaled

train_scaled=scale_d(train3d)
val_scaled  =scale_d(val3d)
test_scaled =scale_d(test3d)

x_train  =np.expand_dims(train_scaled[:,:,0],axis=2)
y_train  =train_scaled[:,:,1]
y_train_e=np.expand_dims(y_train,axis=2)
y_train_s=y_train[:,0]
y_train_s=np.array([1. if x==1 else 0. for x in y_train[:,0]])


x_val   =np.expand_dims(val_scaled[:,:,0],axis=2)
y_val   =val_scaled[:,:,1]
y_val_e =np.expand_dims(y_val,axis=2)
y_val_s =y_val[:,0]
y_val_s=np.array([1. if x==1 else 0. for x in y_val[:,0]])


x_test  =np.expand_dims(test_scaled[:,:,0],axis=2)
y_test  =test_scaled[:,:,1]
y_test_e=np.expand_dims(y_test,axis=2)
y_test_s=y_test[:,0]
y_test_s=np.array([1. if x==1 else 0. for x in y_test[:,0]])

print(x_train.shape,x_val.shape,x_test.shape)
print(y_train.shape,y_val.shape,y_test.shape)
print(y_train_e.shape,y_val_e.shape,y_test_e.shape)
print(y_train_s.shape,y_val_s.shape,y_test_s.shape)
# Out:
# (2808, 500, 1) (793, 500, 1) (1320, 500, 1)
# (2808, 500) (793, 500) (1320, 500)
# (2808, 500, 1) (793, 500, 1) (1320, 500, 1)
# (2808,) (793,) (1320,)

# %%
y_test_s
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
plt.plot(x_train[11,:,0])
plt.show()

# %% [markdown]
# Genereator function

# %%
def batch_generator(data_x,data_y,sequence_length):
    """
    Generator function for creating random batches of training-data.
    """
    df_x=data_x.copy()
    df_y=data_y.copy()
    # Infinite loop.
    while True:
        # Allocate a new array for the batch of input-signals.
        x_shape = (df_x.shape[0], sequence_length, df_x.shape[2])
        x_batch = np.zeros(shape=x_shape, dtype=np.float16)

        # Allocate a new array for the batch of output-signals.
        y_shape = (df_y.shape[0], sequence_length, df_y.shape[2])
        y_batch = np.zeros(shape=y_shape, dtype=np.float16)

        # Fill the batch with random sequences of data.
        for i in range(df_x.shape[0]):
            # Get a random start-index.
            # This points somewhere into the training-data.
            idx = np.random.randint(df_x.shape[1] - sequence_length)
#             print(idx,idx+sequence_length)
            # Copy the sequences of data starting at this index.
            x_batch[i] = df_x[i,idx:idx+sequence_length,:]
            y_batch[i] = df_y[i,idx:idx+sequence_length,:]
        
        yield (x_batch, y_batch)
        
def batch_generator_s(data_x,data_y,sequence_length):
    """
    Generator function for creating random batches of training-data.
    """
    df_x=data_x.copy()
    df_y=data_y.copy()
    # Infinite loop.
    while True:
        # Allocate a new array for the batch of input-signals.
        x_shape = (df_x.shape[0], sequence_length, df_x.shape[2])
        x_batch = np.zeros(shape=x_shape, dtype=np.float16)

        # Allocate a new array for the batch of output-signals.
        y_shape = (df_y.shape[0], 1)
        y_batch = np.zeros(shape=y_shape, dtype=np.float16)

        # Fill the batch with random sequences of data.
        for i in range(df_x.shape[0]):
            # Get a random start-index.
            # This points somewhere into the training-data.
            idx = np.random.randint(df_x.shape[1] - sequence_length)
#             print(idx,idx+sequence_length)
            # Copy the sequences of data starting at this index.
            x_batch[i] = df_x[i,idx:idx+sequence_length,:]
        y_batch = df_y
        
        yield (x_batch, y_batch)

# %% [markdown]
# Function to load best callback

# %%
class GetBest(Callback):
    """Get the best model at the end of training.
	# Arguments
        monitor: quantity to monitor.
        verbose: verbosity mode, 0 or 1.
        mode: one of {auto, min, max}.
            The decision
            to overwrite the current stored weights is made
            based on either the maximization or the
            minimization of the monitored quantity. For `val_acc`,
            this should be `max`, for `val_loss` this should
            be `min`, etc. In `auto` mode, the direction is
            automatically inferred from the name of the monitored quantity.
        period: Interval (number of epochs) between checkpoints.
	# Example
		callbacks = [GetBest(monitor='val_acc', verbose=1, mode='max')]
		mode.fit(X, y, validation_data=(X_eval, Y_eval),
                 callbacks=callbacks)
    """

    def __init__(self, monitor='val_loss', verbose=0,
                 mode='auto', period=1):
        super(GetBest, self).__init__()
        self.monitor = monitor
        self.verbose = verbose
        self.period = period
        self.best_epochs = 0
        self.epochs_since_last_save = 0

        if mode not in ['auto', 'min', 'max']:
            warnings.warn('GetBest mode %s is unknown, '
                          'fallback to auto mode.' % (mode),
                          RuntimeWarning)
            mode = 'auto'

        if mode == 'min':
            self.monitor_op = np.less
            self.best = np.Inf
        elif mode == 'max':
            self.monitor_op = np.greater
            self.best = -np.Inf
        else:
            if 'acc' in self.monitor or self.monitor.startswith('fmeasure'):
                self.monitor_op = np.greater
                self.best = -np.Inf
            else:
                self.monitor_op = np.less
                self.best = np.Inf
                
    def on_train_begin(self, logs=None):
        self.best_weights = self.model.get_weights()

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        self.epochs_since_last_save += 1
        if self.epochs_since_last_save >= self.period:
            self.epochs_since_last_save = 0
            #filepath = self.filepath.format(epoch=epoch + 1, **logs)
            current = logs.get(self.monitor)
            if current is None:
                warnings.warn('Can pick best model only with %s available, '
                              'skipping.' % (self.monitor), RuntimeWarning)
            else:
                if self.monitor_op(current, self.best):
                    if self.verbose > 0:
                        print('\nEpoch %05d: %s improved from %0.5f to %0.5f,'
                              ' storing weights.'
                              % (epoch + 1, self.monitor, self.best,
                                 current))
                    self.best = current
                    self.best_epochs = epoch + 1
                    self.best_weights = self.model.get_weights()
                else:
                    if self.verbose > 0:
                        print('\nEpoch %05d: %s did not improve' %
                              (epoch + 1, self.monitor))            
                    
    def on_train_end(self, logs=None):
        if self.verbose > 0:
            print('Using epoch %05d with %s: %0.5f' % (self.best_epochs, self.monitor,
                                                       self.best))
        self.model.set_weights(self.best_weights)

# %% [markdown]
# # Creating the model

# %% [markdown]
# ## The Best Model

# %%
seq_len = 350
STEPS = 50
EPOCHS = 60

NAME = f"td_fordA-{seq_len}seq_{int(time())}"
model_d = Sequential()

model_d.add(LSTM(units=100,
                 return_sequences=True,
                 input_shape=(seq_len, 1)))

model_d.add(Flatten())
model_d.add(Dense(100, activation='relu'))
model_d.add(Dense(1, activation='sigmoid'))

model_d.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model_d.summary()

# batch_generator_s 함수 정의 필요
def batch_generator_s(x, y, seq_len, batch_size=32):
    num_samples = len(x)
    while True:
        for offset in range(0, num_samples, batch_size):
            batch_x = x[offset:offset+batch_size, :seq_len, :]
            batch_y = y[offset:offset+batch_size]
            yield batch_x, batch_y

# x_train, y_train_s, x_val, y_val_s, x_test, y_test_s 변수가 정의되어 있다고 가정
gen_train = batch_generator_s(x_train, y_train_s, seq_len)
gen_val = batch_generator_s(x_val, y_val_s, seq_len)

tensorboard = TensorBoard(log_dir='Logs/{}'.format(NAME))

checkp = ModelCheckpoint('./best.weights.h5', monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=True, mode='auto', save_freq='epoch')

class GetBest(Callback):
    def __init__(self, monitor='val_accuracy', verbose=1, mode='max'):
        super(GetBest, self).__init__()
        self.monitor = monitor
        self.verbose = verbose
        self.mode = mode
        self.best = -np.Inf if mode == 'max' else np.Inf

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get(self.monitor)
        if self.mode == 'max':
            if current > self.best:
                self.best = current
                if self.verbose:
                    print(f'Epoch {epoch+1}: {self.monitor} improved to {self.best:.5f}')
        else:
            if current < self.best:
                self.best = current
                if self.verbose:
                    print(f'Epoch {epoch+1}: {self.monitor} improved to {self.best:.5f}')

best = GetBest(monitor='val_accuracy', verbose=1, mode='max')

callbacks = [best, tensorboard, checkp]

model_d.fit(gen_train,
            epochs=EPOCHS,
            steps_per_epoch=STEPS,
            validation_data=gen_val,
            validation_steps=STEPS,
            callbacks=callbacks)

scores = model_d.evaluate(x_test[:, :seq_len, :], y_test_s, verbose=0)
print("%s: %.2f%%" % (model_d.metrics_names[1], scores[1] * 100))

pred = draw_roc_keras(model_d, x_test[:, :seq_len, :], y_test_s)
pred = draw_roc_keras(model_d, x_test[:, -seq_len:, :], y_test_s)
print("%s: %.2f%%" % (model_d.metrics_names[1], scores[1] * 100))
# Out:
# c:\Users\SEO\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_28"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_25 (LSTM)                  │ (None, 350, 100)       │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_25 (Flatten)            │ (None, 35000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 100)            │     3,500,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,541,001 (13.51 MB)
#  Trainable params: 3,541,001 (13.51 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.5745 - loss: 0.7558Epoch 1: val_accuracy improved to 0.63934
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 278ms/step - accuracy: 0.5748 - loss: 0.7547 - val_accuracy: 0.6393 - val_loss: 0.6231
# Epoch 2/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 14s 281ms/step - accuracy: 0.6745 - loss: 0.6081 - val_accuracy: 0.6255 - val_loss: 0.6393
# Epoch 3/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.7048 - loss: 0.5900Epoch 3: val_accuracy improved to 0.66078
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 310ms/step - accuracy: 0.7049 - loss: 0.5898 - val_accuracy: 0.6608 - val_loss: 0.6082
# Epoch 4/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 310ms/step - accuracy: 0.7087 - loss: 0.5598 - val_accuracy: 0.6330 - val_loss: 0.7485
# Epoch 5/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 332ms/step - accuracy: 0.7063 - loss: 0.5623 - val_accuracy: 0.6356 - val_loss: 0.7552
# Epoch 6/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.7620 - loss: 0.4996Epoch 6: val_accuracy improved to 0.69231
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 355ms/step - accuracy: 0.7624 - loss: 0.4991 - val_accuracy: 0.6923 - val_loss: 0.6305
# Epoch 7/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 313ms/step - accuracy: 0.8078 - loss: 0.4412 - val_accuracy: 0.6633 - val_loss: 0.7040
# Epoch 8/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 315ms/step - accuracy: 0.8207 - loss: 0.4362 - val_accuracy: 0.6835 - val_loss: 0.6552
# Epoch 9/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.8562 - loss: 0.3487Epoch 9: val_accuracy improved to 0.71122
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 321ms/step - accuracy: 0.8562 - loss: 0.3486 - val_accuracy: 0.7112 - val_loss: 0.6064
# Epoch 10/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 310ms/step - accuracy: 0.8779 - loss: 0.3119 - val_accuracy: 0.7024 - val_loss: 0.6970
# Epoch 11/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9122 - loss: 0.2507Epoch 11: val_accuracy improved to 0.72888
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 325ms/step - accuracy: 0.9121 - loss: 0.2508 - val_accuracy: 0.7289 - val_loss: 0.5735
# Epoch 12/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 402ms/step - accuracy: 0.9085 - loss: 0.2435 - val_accuracy: 0.6759 - val_loss: 0.9338
# Epoch 13/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9286 - loss: 0.1949Epoch 13: val_accuracy improved to 0.79319
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 435ms/step - accuracy: 0.9285 - loss: 0.1951 - val_accuracy: 0.7932 - val_loss: 0.5686
# Epoch 14/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9169 - loss: 0.2152Epoch 14: val_accuracy improved to 0.80706
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - accuracy: 0.9169 - loss: 0.2153 - val_accuracy: 0.8071 - val_loss: 0.6311
# Epoch 15/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 419ms/step - accuracy: 0.9270 - loss: 0.1718 - val_accuracy: 0.7730 - val_loss: 0.6288
# Epoch 16/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 296ms/step - accuracy: 0.9226 - loss: 0.1635 - val_accuracy: 0.7730 - val_loss: 0.6842
# Epoch 17/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.9380 - loss: 0.1730Epoch 17: val_accuracy improved to 0.82346
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 293ms/step - accuracy: 0.9380 - loss: 0.1727 - val_accuracy: 0.8235 - val_loss: 0.4219
# Epoch 18/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 313ms/step - accuracy: 0.9589 - loss: 0.1169 - val_accuracy: 0.8184 - val_loss: 0.4999
# Epoch 19/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9469 - loss: 0.1227Epoch 19: val_accuracy improved to 0.84363
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 306ms/step - accuracy: 0.9470 - loss: 0.1227 - val_accuracy: 0.8436 - val_loss: 0.4277
# Epoch 20/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9517 - loss: 0.1074 - val_accuracy: 0.8197 - val_loss: 0.5959
# Epoch 21/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 13s 259ms/step - accuracy: 0.9532 - loss: 0.1207 - val_accuracy: 0.7718 - val_loss: 0.9355
# Epoch 22/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 445ms/step - accuracy: 0.9651 - loss: 0.0877 - val_accuracy: 0.8398 - val_loss: 0.5241
# Epoch 23/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 444ms/step - accuracy: 0.9799 - loss: 0.0567 - val_accuracy: 0.8285 - val_loss: 0.6181
# Epoch 24/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9820 - loss: 0.0473Epoch 24: val_accuracy improved to 0.85876
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 449ms/step - accuracy: 0.9821 - loss: 0.0472 - val_accuracy: 0.8588 - val_loss: 0.4946
# Epoch 25/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 448ms/step - accuracy: 0.9922 - loss: 0.0324 - val_accuracy: 0.8588 - val_loss: 0.5368
# Epoch 26/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 444ms/step - accuracy: 0.9913 - loss: 0.0315 - val_accuracy: 0.8512 - val_loss: 0.5770
# Epoch 27/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 437ms/step - accuracy: 0.9955 - loss: 0.0138 - val_accuracy: 0.8588 - val_loss: 0.4913
# Epoch 28/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9987 - loss: 0.0109Epoch 28: val_accuracy improved to 0.86381
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 448ms/step - accuracy: 0.9987 - loss: 0.0108 - val_accuracy: 0.8638 - val_loss: 0.5915
# Epoch 29/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 1.0000 - loss: 0.0039Epoch 29: val_accuracy improved to 0.87516
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 386ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8752 - val_loss: 0.5526
# Epoch 30/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 1.0000 - loss: 0.0012Epoch 30: val_accuracy improved to 0.87642
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 436ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8764 - val_loss: 0.5680
# Epoch 31/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - accuracy: 1.0000 - loss: 8.9411e-04 - val_accuracy: 0.8714 - val_loss: 0.5720
# Epoch 32/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 241ms/step - accuracy: 1.0000 - loss: 7.0089e-04 - val_accuracy: 0.8714 - val_loss: 0.5841
# Epoch 33/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 242ms/step - accuracy: 1.0000 - loss: 5.8716e-04 - val_accuracy: 0.8739 - val_loss: 0.5853
# Epoch 34/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 217ms/step - accuracy: 1.0000 - loss: 5.6531e-04 - val_accuracy: 0.8714 - val_loss: 0.5951
# Epoch 35/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 219ms/step - accuracy: 1.0000 - loss: 4.4809e-04 - val_accuracy: 0.8726 - val_loss: 0.5977
# Epoch 36/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - accuracy: 1.0000 - loss: 4.3066e-04 - val_accuracy: 0.8752 - val_loss: 0.6040
# Epoch 37/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 447ms/step - accuracy: 1.0000 - loss: 3.9623e-04 - val_accuracy: 0.8752 - val_loss: 0.6093
# Epoch 38/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 443ms/step - accuracy: 1.0000 - loss: 3.6095e-04 - val_accuracy: 0.8752 - val_loss: 0.6124
# Epoch 39/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 440ms/step - accuracy: 1.0000 - loss: 3.2862e-04 - val_accuracy: 0.8752 - val_loss: 0.6205
# Epoch 40/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 433ms/step - accuracy: 1.0000 - loss: 2.6477e-04 - val_accuracy: 0.8752 - val_loss: 0.6208
# Epoch 41/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 385ms/step - accuracy: 1.0000 - loss: 2.8785e-04 - val_accuracy: 0.8752 - val_loss: 0.6283
# Epoch 42/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 423ms/step - accuracy: 1.0000 - loss: 2.4044e-04 - val_accuracy: 0.8726 - val_loss: 0.6296
# Epoch 43/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 443ms/step - accuracy: 1.0000 - loss: 2.2603e-04 - val_accuracy: 0.8726 - val_loss: 0.6353
# Epoch 44/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 22s 443ms/step - accuracy: 1.0000 - loss: 2.1600e-04 - val_accuracy: 0.8726 - val_loss: 0.6388
# Epoch 45/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 422ms/step - accuracy: 1.0000 - loss: 1.8648e-04 - val_accuracy: 0.8726 - val_loss: 0.6416
# Epoch 46/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 13s 271ms/step - accuracy: 1.0000 - loss: 1.8890e-04 - val_accuracy: 0.8714 - val_loss: 0.6476
# Epoch 47/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 325ms/step - accuracy: 1.0000 - loss: 1.4883e-04 - val_accuracy: 0.8739 - val_loss: 0.6481
# Epoch 48/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 298ms/step - accuracy: 1.0000 - loss: 1.6747e-04 - val_accuracy: 0.8726 - val_loss: 0.6540
# Epoch 49/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 305ms/step - accuracy: 1.0000 - loss: 1.4626e-04 - val_accuracy: 0.8739 - val_loss: 0.6550
# Epoch 50/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 357ms/step - accuracy: 1.0000 - loss: 1.3839e-04 - val_accuracy: 0.8726 - val_loss: 0.6603
# Epoch 51/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 357ms/step - accuracy: 1.0000 - loss: 1.3531e-04 - val_accuracy: 0.8726 - val_loss: 0.6626
# Epoch 52/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 375ms/step - accuracy: 1.0000 - loss: 1.1369e-04 - val_accuracy: 0.8726 - val_loss: 0.6655
# Epoch 53/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 349ms/step - accuracy: 1.0000 - loss: 1.1641e-04 - val_accuracy: 0.8726 - val_loss: 0.6706
# Epoch 54/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 368ms/step - accuracy: 1.0000 - loss: 1.0141e-04 - val_accuracy: 0.8726 - val_loss: 0.6712
# Epoch 55/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 373ms/step - accuracy: 1.0000 - loss: 1.1392e-04 - val_accuracy: 0.8726 - val_loss: 0.6762
# Epoch 56/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 414ms/step - accuracy: 1.0000 - loss: 1.0109e-04 - val_accuracy: 0.8726 - val_loss: 0.6770
# Epoch 57/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 421ms/step - accuracy: 1.0000 - loss: 1.0274e-04 - val_accuracy: 0.8726 - val_loss: 0.6821
# Epoch 58/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 414ms/step - accuracy: 1.0000 - loss: 9.4989e-05 - val_accuracy: 0.8739 - val_loss: 0.6838
# Epoch 59/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 389ms/step - accuracy: 1.0000 - loss: 8.1702e-05 - val_accuracy: 0.8726 - val_loss: 0.6865
# Epoch 60/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - accuracy: 1.0000 - loss: 7.8390e-05 - val_accuracy: 0.8726 - val_loss: 0.6911
# compile_metrics: 87.50%
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step
# compile_metrics: 87.50%

# %%
scores = model_d.evaluate([x_test[:,-seq_len:,:]], y_test_s, verbose=0)

print("%s: %.2f%%" % (model_d.metrics_names[1], scores[1]*100))
pred=draw_roc_keras(model_d,[x_test[:,:seq_len,:]],y_test_s)
pred=draw_roc_keras(model_d,[x_test[:,-seq_len:,:]],y_test_s)
print("%s: %.2f%%" % (model_d.metrics_names[1], scores[1]*100))
# Out:
# compile_metrics: 50.76%
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step
# compile_metrics: 50.76%

# %%
gen_test =batch_generator_s(x_test,y_test_s,seq_len)
for i in range(100):
    x_batch, y_batch= next(gen_test)
    scores = model_d.evaluate([x_batch], y_batch, verbose=0)
    print("%s: %.2f%%" % (model_d.metrics_names[1], scores[1]*100))
#     pred=draw_roc_keras(model_d,[x_batch],y_batch)
# Out:
# compile_metrics: 90.62%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 78.12%
# compile_metrics: 90.62%
# compile_metrics: 84.38%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 78.12%
# compile_metrics: 87.50%
# compile_metrics: 84.38%
# compile_metrics: 75.00%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 93.75%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 84.38%
# compile_metrics: 81.25%
# compile_metrics: 81.25%
# compile_metrics: 84.38%
# compile_metrics: 93.75%
# compile_metrics: 90.62%
# compile_metrics: 84.38%
# compile_metrics: 81.25%
# compile_metrics: 81.25%
# compile_metrics: 84.38%
# compile_metrics: 78.12%
# compile_metrics: 93.75%
# compile_metrics: 68.75%
# compile_metrics: 90.62%
# compile_metrics: 84.38%
# compile_metrics: 84.38%
# compile_metrics: 84.38%
# compile_metrics: 78.12%
# compile_metrics: 81.25%
# compile_metrics: 87.50%
# compile_metrics: 81.25%
# compile_metrics: 62.50%
# compile_metrics: 90.62%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 78.12%
# compile_metrics: 90.62%
# compile_metrics: 84.38%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 78.12%
# compile_metrics: 87.50%
# compile_metrics: 84.38%
# compile_metrics: 75.00%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 93.75%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 84.38%
# compile_metrics: 81.25%
# compile_metrics: 81.25%
# compile_metrics: 84.38%
# compile_metrics: 93.75%
# compile_metrics: 90.62%
# compile_metrics: 84.38%
# compile_metrics: 81.25%
# compile_metrics: 81.25%
# compile_metrics: 84.38%
# compile_metrics: 78.12%
# compile_metrics: 93.75%
# compile_metrics: 68.75%
# compile_metrics: 90.62%
# compile_metrics: 84.38%
# compile_metrics: 84.38%
# compile_metrics: 84.38%
# compile_metrics: 78.12%
# compile_metrics: 81.25%
# compile_metrics: 87.50%
# compile_metrics: 81.25%
# compile_metrics: 62.50%
# compile_metrics: 90.62%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 78.12%
# compile_metrics: 90.62%
# compile_metrics: 84.38%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 78.12%
# compile_metrics: 87.50%
# compile_metrics: 84.38%
# compile_metrics: 75.00%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 93.75%

# %%
# # load weights
# model.load_weights("Models/best.hdf5")
# # Compile model (required to make predictions)
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# print("Created model and loaded weights from file")
# # load pima indians dataset
# # # estimate accuracy on whole dataset using loaded weights
# # scores = model.evaluate(X, Y, verbose=0)
# # print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# pred=draw_roc_keras(model,[x_test[:,-seq_len:,:]],y_test_s)

# %% [markdown]
# #### Experimenting

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler 
from sklearn.metrics import roc_curve, auc
from scipy.io.arff import loadarff 

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, GRU, Embedding, LSTM, Flatten, MaxPooling1D, BatchNormalization, Dropout, TimeDistributed, Conv1D, Conv2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
import matplotlib.pyplot as plt

from time import time

def draw_roc_keras(model, xt, yt):
    predictions = model.predict(xt)
    if predictions.shape[1] == 2:
        predictions = predictions[:, 1]  # Use the second column for binary classification probability

    fpr, tpr, thr = roc_curve(yt, predictions)
    roc_auc = auc(fpr, tpr)
    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()
    return predictions

seq_len = 350
STEPS = 20
EPOCHS = 60

NAME = f"conv1d_fordA-{seq_len}seq_{int(time())}"
model_d = Sequential()

model_d.add(LSTM(units=100,
                 return_sequences=True,
                 input_shape=(seq_len, 1)))

model_d.add(Conv1D(filters=100, 
                   kernel_size=100, 
                   activation='relu'))

model_d.add(Conv1D(filters=100, 
                   kernel_size=20, 
                   activation='relu'))

model_d.add(Conv1D(filters=100, 
                   kernel_size=10, 
                   activation='relu'))

model_d.add(Conv1D(filters=100, 
                   kernel_size=5, 
                   activation='relu'))

model_d.add(Conv1D(filters=100, 
                   kernel_size=3, 
                   activation='relu'))

model_d.add(Flatten())
model_d.add(Dense(1, activation='sigmoid'))

model_d.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# batch_generator_s 함수 정의 필요
def batch_generator_s(x, y, seq_len, batch_size=32):
    num_samples = len(x)
    while True:
        for offset in range(0, num_samples, batch_size):
            batch_x = x[offset:offset+batch_size, :seq_len, :]
            batch_y = y[offset:offset+batch_size]
            yield batch_x, batch_y

# x_train, y_train_s, x_val, y_val_s, x_test, y_test_s 변수가 정의되어 있다고 가정
gen_train = batch_generator_s(x_train, y_train_s, seq_len)
gen_val = batch_generator_s(x_val, y_val_s, seq_len)

tensorboard = TensorBoard(log_dir='Logs/{}'.format(NAME))

checkp = ModelCheckpoint('model_ds/best.weights.h5', monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=True, mode='auto', save_freq='epoch')

class GetBest(Callback):
    def __init__(self, monitor='val_accuracy', verbose=1, mode='max'):
        super(GetBest, self).__init__()
        self.monitor = monitor
        self.verbose = verbose
        self.mode = mode
        self.best = -np.Inf if mode == 'max' else np.Inf

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get(self.monitor)
        if self.mode == 'max':
            if current > self.best:
                self.best = current
                if self.verbose:
                    print(f'Epoch {epoch+1}: {self.monitor} improved to {self.best:.5f}')
        else:
            if current < self.best:
                self.best = current
                if self.verbose:
                    print(f'Epoch {epoch+1}: {self.monitor} improved to {self.best:.5f}')

best = GetBest(monitor='val_accuracy', verbose=1, mode='max')

callbacks = [best, tensorboard, checkp]

model_d.fit(gen_train,
            epochs=EPOCHS,
            steps_per_epoch=STEPS,
            validation_data=gen_val,
            validation_steps=STEPS,
            callbacks=callbacks)

model_d.summary()

scores = model_d.evaluate(x_test[:, -seq_len:, :], y_test_s, verbose=0)
print("%s: %.2f%%" % (model_d.metrics_names[1], scores[1] * 100))

pred = draw_roc_keras(model_d, x_test[:, :seq_len, :], y_test_s)
pred = draw_roc_keras(model_d, x_test[:, -seq_len:, :], y_test_s)
print("%s: %.2f%%" % (model_d.metrics_names[1], scores[1] * 100))
# Out:
# Epoch 1/60
# c:\Users\SEO\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.5736 - loss: 0.6846Epoch 1: val_accuracy improved to 0.56719
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 862ms/step - accuracy: 0.5722 - loss: 0.6847 - val_accuracy: 0.5672 - val_loss: 0.6726
# Epoch 2/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.5931 - loss: 0.6696Epoch 2: val_accuracy improved to 0.59242
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 899ms/step - accuracy: 0.5959 - loss: 0.6679 - val_accuracy: 0.5924 - val_loss: 0.6821
# Epoch 3/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 701ms/step - accuracy: 0.7106 - loss: 0.5520Epoch 3: val_accuracy improved to 0.72354
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 926ms/step - accuracy: 0.7112 - loss: 0.5516 - val_accuracy: 0.7235 - val_loss: 0.5468
# Epoch 4/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.7487 - loss: 0.5336Epoch 4: val_accuracy improved to 0.79305
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 931ms/step - accuracy: 0.7506 - loss: 0.5311 - val_accuracy: 0.7930 - val_loss: 0.4885
# Epoch 5/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.7619 - loss: 0.4976Epoch 5: val_accuracy improved to 0.81201
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 956ms/step - accuracy: 0.7615 - loss: 0.4987 - val_accuracy: 0.8120 - val_loss: 0.4450
# Epoch 6/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.8328 - loss: 0.3923Epoch 6: val_accuracy improved to 0.86875
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.8331 - loss: 0.3921 - val_accuracy: 0.8687 - val_loss: 0.3499
# Epoch 7/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 882ms/step - accuracy: 0.8795 - loss: 0.2994Epoch 7: val_accuracy improved to 0.89258
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.8803 - loss: 0.2981 - val_accuracy: 0.8926 - val_loss: 0.3092
# Epoch 8/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 922ms/step - accuracy: 0.8710 - loss: 0.3380 - val_accuracy: 0.8784 - val_loss: 0.3068
# Epoch 9/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 962ms/step - accuracy: 0.8777 - loss: 0.2745 - val_accuracy: 0.8926 - val_loss: 0.3050
# Epoch 10/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 961ms/step - accuracy: 0.8798 - loss: 0.2897 - val_accuracy: 0.8768 - val_loss: 0.2909
# Epoch 11/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - accuracy: 0.8952 - loss: 0.2322Epoch 11: val_accuracy improved to 0.90938
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 999ms/step - accuracy: 0.8955 - loss: 0.2315 - val_accuracy: 0.9094 - val_loss: 0.2492
# Epoch 12/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 795ms/step - accuracy: 0.9192 - loss: 0.2288Epoch 12: val_accuracy improved to 0.91469
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9186 - loss: 0.2299 - val_accuracy: 0.9147 - val_loss: 0.2391
# Epoch 13/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 829ms/step - accuracy: 0.9086 - loss: 0.2264 - val_accuracy: 0.9131 - val_loss: 0.2389
# Epoch 14/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 987ms/step - accuracy: 0.8974 - loss: 0.2357 - val_accuracy: 0.9052 - val_loss: 0.2783
# Epoch 15/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9274 - loss: 0.1762 - val_accuracy: 0.8942 - val_loss: 0.2758
# Epoch 16/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 918ms/step - accuracy: 0.9290 - loss: 0.1547 - val_accuracy: 0.9016 - val_loss: 0.2628
# Epoch 17/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - accuracy: 0.9040 - loss: 0.2275Epoch 17: val_accuracy improved to 0.92575
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 945ms/step - accuracy: 0.9044 - loss: 0.2272 - val_accuracy: 0.9258 - val_loss: 0.2450
# Epoch 18/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 938ms/step - accuracy: 0.9183 - loss: 0.1684 - val_accuracy: 0.8594 - val_loss: 0.4032
# Epoch 19/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 900ms/step - accuracy: 0.9269 - loss: 0.2072 - val_accuracy: 0.9100 - val_loss: 0.2509
# Epoch 20/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9184 - loss: 0.2286 - val_accuracy: 0.9036 - val_loss: 0.2254
# Epoch 21/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 952ms/step - accuracy: 0.9279 - loss: 0.1732 - val_accuracy: 0.9234 - val_loss: 0.2188
# Epoch 22/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.9210 - loss: 0.1764 - val_accuracy: 0.9210 - val_loss: 0.2447
# Epoch 23/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 852ms/step - accuracy: 0.9353 - loss: 0.1646 - val_accuracy: 0.9179 - val_loss: 0.2116
# Epoch 24/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 786ms/step - accuracy: 0.9357 - loss: 0.1483 - val_accuracy: 0.8942 - val_loss: 0.3155
# Epoch 25/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 777ms/step - accuracy: 0.9567 - loss: 0.1415 - val_accuracy: 0.9163 - val_loss: 0.2288
# Epoch 26/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 955ms/step - accuracy: 0.9218 - loss: 0.2010 - val_accuracy: 0.8953 - val_loss: 0.2604
# Epoch 27/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 961ms/step - accuracy: 0.9236 - loss: 0.2006 - val_accuracy: 0.9131 - val_loss: 0.3410
# Epoch 28/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 940ms/step - accuracy: 0.9286 - loss: 0.1867 - val_accuracy: 0.9194 - val_loss: 0.2087
# Epoch 29/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 933ms/step - accuracy: 0.9338 - loss: 0.1438 - val_accuracy: 0.8847 - val_loss: 0.3552
# Epoch 30/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9349 - loss: 0.1540 - val_accuracy: 0.9115 - val_loss: 0.2565
# Epoch 31/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 966ms/step - accuracy: 0.9296 - loss: 0.1674 - val_accuracy: 0.9219 - val_loss: 0.2301
# Epoch 32/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 924ms/step - accuracy: 0.9377 - loss: 0.1755 - val_accuracy: 0.9163 - val_loss: 0.3266
# Epoch 33/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 948ms/step - accuracy: 0.9413 - loss: 0.1367 - val_accuracy: 0.9179 - val_loss: 0.2555
# Epoch 34/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 922ms/step - accuracy: 0.9502 - loss: 0.1136 - val_accuracy: 0.9242 - val_loss: 0.2926
# Epoch 35/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 873ms/step - accuracy: 0.9466 - loss: 0.1384 - val_accuracy: 0.9194 - val_loss: 0.2385
# Epoch 36/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 898ms/step - accuracy: 0.9359 - loss: 0.1862 - val_accuracy: 0.9187 - val_loss: 0.2498
# Epoch 37/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 977ms/step - accuracy: 0.9464 - loss: 0.1204 - val_accuracy: 0.9226 - val_loss: 0.2958
# Epoch 38/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9640 - loss: 0.0832 - val_accuracy: 0.9100 - val_loss: 0.3292
# Epoch 39/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 965ms/step - accuracy: 0.9306 - loss: 0.1426 - val_accuracy: 0.9052 - val_loss: 0.3432
# Epoch 40/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 934ms/step - accuracy: 0.9038 - loss: 0.1759 - val_accuracy: 0.9021 - val_loss: 0.3197
# Epoch 41/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.9500 - loss: 0.1461Epoch 41: val_accuracy improved to 0.92813
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 950ms/step - accuracy: 0.9500 - loss: 0.1457 - val_accuracy: 0.9281 - val_loss: 0.2542
# Epoch 42/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9575 - loss: 0.1100 - val_accuracy: 0.9210 - val_loss: 0.2959
# Epoch 43/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9549 - loss: 0.1161 - val_accuracy: 0.9226 - val_loss: 0.2706
# Epoch 44/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 925ms/step - accuracy: 0.9524 - loss: 0.1275 - val_accuracy: 0.9084 - val_loss: 0.3377
# Epoch 45/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 941ms/step - accuracy: 0.9464 - loss: 0.1485 - val_accuracy: 0.9131 - val_loss: 0.3086
# Epoch 46/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 994ms/step - accuracy: 0.9480 - loss: 0.1227 - val_accuracy: 0.9094 - val_loss: 0.3013
# Epoch 47/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9411 - loss: 0.1302 - val_accuracy: 0.9194 - val_loss: 0.3009
# Epoch 48/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 927ms/step - accuracy: 0.9300 - loss: 0.1934 - val_accuracy: 0.8752 - val_loss: 0.2920
# Epoch 49/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 18s 917ms/step - accuracy: 0.9320 - loss: 0.1960 - val_accuracy: 0.9036 - val_loss: 0.3058
# Epoch 50/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 946ms/step - accuracy: 0.9327 - loss: 0.1317 - val_accuracy: 0.9131 - val_loss: 0.2654
# Epoch 51/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9495 - loss: 0.1223 - val_accuracy: 0.9234 - val_loss: 0.2915
# Epoch 52/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 820ms/step - accuracy: 0.9732 - loss: 0.0717 - val_accuracy: 0.9021 - val_loss: 0.3732
# Epoch 53/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 16s 822ms/step - accuracy: 0.9338 - loss: 0.1357 - val_accuracy: 0.8926 - val_loss: 0.3437
# Epoch 54/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.9274 - loss: 0.1694 - val_accuracy: 0.9068 - val_loss: 0.2781
# Epoch 55/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9632 - loss: 0.1102 - val_accuracy: 0.9052 - val_loss: 0.2673
# Epoch 56/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.9614 - loss: 0.0897 - val_accuracy: 0.9266 - val_loss: 0.2959
# Epoch 57/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9701 - loss: 0.0794 - val_accuracy: 0.9100 - val_loss: 0.3657
# Epoch 58/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9572 - loss: 0.1018 - val_accuracy: 0.9242 - val_loss: 0.2538
# Epoch 59/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 873ms/step - accuracy: 0.9755 - loss: 0.0629 - val_accuracy: 0.9147 - val_loss: 0.4382
# Epoch 60/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 866ms/step - accuracy: 0.9864 - loss: 0.0592 - val_accuracy: 0.9021 - val_loss: 0.4730
# Model: "sequential_27"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_24 (LSTM)                  │ (None, 350, 100)       │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_20 (Conv1D)              │ (None, 251, 100)       │     1,000,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_21 (Conv1D)              │ (None, 232, 100)       │       200,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_22 (Conv1D)              │ (None, 223, 100)       │       100,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_23 (Conv1D)              │ (None, 219, 100)       │        50,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_24 (Conv1D)              │ (None, 217, 100)       │        30,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_24 (Flatten)            │ (None, 21700)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 1)              │        21,701 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,329,005 (16.51 MB)
#  Trainable params: 1,443,001 (5.50 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,886,004 (11.01 MB)
# compile_metrics: 90.30%
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 266ms/step
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 9s 204ms/step
# compile_metrics: 90.30%

# %%
scores = model_d.evaluate([x_test[:,-seq_len:,:]], y_test_s, verbose=0)
print("%s: %.2f%%" % (model_d.metrics_names[1], scores[1]*100))
pred=draw_roc_keras(model_d,[x_test[:,:seq_len,:]],y_test_s)
pred=draw_roc_keras(model_d,[x_test[:,-seq_len:,:]],y_test_s)
print("%s: %.2f%%" % (model_d.metrics_names[1], scores[1]*100))
# Out:
# compile_metrics: 90.30%
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 8s 199ms/step
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 8s 185ms/step
# compile_metrics: 90.30%

# %%
gen_test =batch_generator_s(x_test,y_test_s,seq_len)
for i in range(100):
    x_batch, y_batch= next(gen_test)
    scores = model_d.evaluate([x_batch], y_batch, verbose=0)
    print("%s: %.2f%%" % (model_d.metrics_names[1], scores[1]*100))
#     pred=draw_roc_keras(model_d,[x_batch],y_batch)
# Out:
# compile_metrics: 93.75%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 84.38%
# compile_metrics: 93.75%
# compile_metrics: 100.00%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# compile_metrics: 93.75%
# compile_metrics: 90.62%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 87.50%
# compile_metrics: 81.25%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 93.75%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# compile_metrics: 84.38%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 96.88%
# compile_metrics: 96.88%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 87.50%
# compile_metrics: 87.50%
# compile_metrics: 90.62%
# compile_metrics: 84.38%
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 84.38%
# compile_metrics: 93.75%
# compile_metrics: 96.88%
# compile_metrics: 84.38%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# compile_metrics: 93.75%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 84.38%
# compile_metrics: 93.75%
# compile_metrics: 100.00%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# compile_metrics: 93.75%
# compile_metrics: 90.62%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 87.50%
# compile_metrics: 81.25%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 93.75%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# compile_metrics: 84.38%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 96.88%
# compile_metrics: 96.88%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 87.50%
# compile_metrics: 87.50%
# compile_metrics: 90.62%
# compile_metrics: 84.38%
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 84.38%
# compile_metrics: 93.75%
# compile_metrics: 96.88%
# compile_metrics: 84.38%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# compile_metrics: 93.75%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 84.38%
# compile_metrics: 93.75%
# compile_metrics: 100.00%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# compile_metrics: 93.75%
# compile_metrics: 90.62%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 87.50%
# compile_metrics: 81.25%
# compile_metrics: 96.88%
# compile_metrics: 90.62%

# %%
gen_test = batch_generator_s(x_test, y_test_s, seq_len)

# 테스트 데이터셋을 평가합니다.
for i in range(100):
    x_batch, y_batch = next(gen_test)
    scores = model_d.evaluate([x_batch], y_batch, verbose=0)
    print("%s: %.2f%%" % (model_d.metrics_names[1], scores[1]*100))
# Out:
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 87.50%
# compile_metrics: 84.38%
# compile_metrics: 81.25%
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 87.50%
# compile_metrics: 90.62%
# compile_metrics: 78.12%
# compile_metrics: 90.62%
# compile_metrics: 81.25%
# compile_metrics: 81.25%
# compile_metrics: 90.62%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 78.12%
# compile_metrics: 84.38%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# compile_metrics: 90.62%
# compile_metrics: 96.88%
# compile_metrics: 81.25%
# compile_metrics: 75.00%
# compile_metrics: 81.25%
# compile_metrics: 81.25%
# compile_metrics: 93.75%
# compile_metrics: 81.25%
# compile_metrics: 90.62%
# compile_metrics: 87.50%
# compile_metrics: 90.62%
# compile_metrics: 87.50%
# compile_metrics: 84.38%
# compile_metrics: 84.38%
# compile_metrics: 87.50%
# compile_metrics: 81.25%
# compile_metrics: 87.50%
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 87.50%
# compile_metrics: 84.38%
# compile_metrics: 81.25%
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 87.50%
# compile_metrics: 90.62%
# compile_metrics: 78.12%
# compile_metrics: 90.62%
# compile_metrics: 81.25%
# compile_metrics: 81.25%
# compile_metrics: 90.62%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 96.88%
# compile_metrics: 90.62%
# compile_metrics: 90.62%
# compile_metrics: 78.12%
# compile_metrics: 84.38%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# compile_metrics: 90.62%
# compile_metrics: 96.88%
# compile_metrics: 81.25%
# compile_metrics: 75.00%
# compile_metrics: 81.25%
# compile_metrics: 81.25%
# compile_metrics: 93.75%
# compile_metrics: 81.25%
# compile_metrics: 90.62%
# compile_metrics: 87.50%
# compile_metrics: 90.62%
# compile_metrics: 87.50%
# compile_metrics: 84.38%
# compile_metrics: 84.38%
# compile_metrics: 87.50%
# compile_metrics: 81.25%
# compile_metrics: 87.50%
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 87.50%
# compile_metrics: 84.38%
# compile_metrics: 81.25%
# compile_metrics: 90.62%
# compile_metrics: 93.75%
# compile_metrics: 87.50%
# compile_metrics: 90.62%
# compile_metrics: 78.12%
# compile_metrics: 90.62%
# compile_metrics: 81.25%
# compile_metrics: 81.25%
# compile_metrics: 90.62%
# compile_metrics: 87.50%
# compile_metrics: 93.75%
# (320, 1)
# array([[7.96235740e-01],
#        [1.41634562e-04],
#        [1.00000000e+00],
#        [2.43274830e-02],
#        [9.83282745e-01],
#        [7.17957818e-08],
#        [1.00000000e+00],
#        [9.99838948e-01],
#        [5.33031175e-09],
#        [2.97946166e-02],
#        [1.00000000e+00],
#        [9.99943078e-01],
#        [1.00000000e+00],
#        [1.39702051e-05],
#        [5.82422854e-06],
#        [9.99999881e-01],
#        [7.51161123e-13],
#        [9.99910176e-01],
#        [1.79494646e-06],
#        [1.00000000e+00],
#        [9.96144056e-01],
#        [1.95737655e-07],
#        [2.94016005e-04],
#        [1.00000000e+00],
#        [2.21092582e-15],
#        [2.68725269e-02],
#        [2.46817905e-15],
#        [1.00000000e+00],
#        [3.79721797e-03],
#        [9.99999940e-01],
#        [9.99999940e-01],
#        [3.97104827e-07],
#        [9.02230144e-01],
#        [1.00000000e+00],
#        [4.24391270e-01],
#        [1.00000000e+00],
#        [4.29510419e-06],
#        [1.00000000e+00],
#        [1.03352962e-08],
#        [1.00000000e+00],
#        [9.99990642e-01],
#        [3.61380756e-01],
#        [9.97181654e-01],
#        [5.38535357e-01],
#        [1.28008587e-05],
#        [2.19167590e-01],
#        [6.89748209e-03],
#        [9.99999940e-01],
#        [9.99995589e-01],
#        [1.00000000e+00],
#        [9.99905169e-01],
#        [9.94480431e-01],
#        [6.53708821e-06],
#        [3.22830737e-01],
#        [4.14309760e-08],
#        [1.70499290e-04],
#        [7.74678648e-01],
#        [1.93252577e-03],
#        [1.00000000e+00],
#        [2.05709426e-07],
#        [9.98447776e-01],
#        [9.99960542e-01],
#        [1.00000000e+00],
#        [9.99999523e-01],
#        [1.00000000e+00],
#        [3.83814726e-15],
#        [1.00000000e+00],
#        [2.03809553e-10],
#        [1.11179120e-15],
#        [1.86441609e-11],
#        [4.96829443e-06],
#        [1.80589416e-06],
#        [9.99950945e-01],
#        [1.34394795e-05],
#        [9.17147875e-01],
#        [2.84637325e-04],
#        [9.99951303e-01],
#        [8.19835441e-06],
#        [1.00000000e+00],
#        [7.45732564e-07],
#        [9.78141930e-03],
#        [5.69456184e-11],
#        [5.46682495e-05],
#        [1.00000000e+00],
#        [1.85697886e-07],
#        [1.00000000e+00],
#        [6.47597293e-16],
#        [5.79308435e-05],
#        [1.61581236e-04],
#        [9.99997497e-01],
#        [1.35209970e-03],
#        [9.99999166e-01],
#        [9.99968112e-01],
#        [1.00000000e+00],
#        [9.99999642e-01],
#        [1.01344738e-10],
#        [7.91778206e-04],
#        [5.83472456e-06],
#        [7.24239158e-07],
#        [1.00000000e+00],
#        [9.93973255e-01],
#        [1.00000000e+00],
#        [9.99999583e-01],
#        [4.65233602e-10],
#        [9.92170095e-01],
#        [1.00000000e+00],
#        [2.96477545e-08],
#        [4.29744273e-03],
#        [9.99999166e-01],
#        [4.61021066e-03],
#        [7.57466376e-01],
#        [3.75790599e-08],
#        [9.05677795e-01],
#        [9.99985456e-01],
#        [4.53523971e-05],
#        [2.68437982e-01],
#        [9.54002440e-01],
#        [1.36440538e-03],
#        [5.65606236e-01],
#        [3.43624601e-10],
#        [1.00000000e+00],
#        [1.04756943e-07],
#        [8.02993265e-14],
#        [1.00000000e+00],
#        [9.99999940e-01],
#        [3.74494642e-02],
#        [9.99952376e-01],
#        [3.56280507e-04],
#        [2.78200901e-06],
#        [1.56672322e-03],
#        [9.57862358e-04],
#        [2.01445218e-05],
#        [4.06727951e-04],
#        [1.00000000e+00],
#        [1.00000000e+00],
#        [8.52866527e-11],
#        [2.61376641e-12],
#        [1.00000000e+00],
#        [6.07780631e-11],
#        [9.97486413e-01],
#        [2.59984494e-03],
#        [5.98734259e-05],
#        [8.68967414e-01],
#        [9.99999821e-01],
#        [9.99999166e-01],
#        [4.94540586e-07],
#        [5.69585666e-07],
#        [9.99999821e-01],
#        [1.03763863e-03],
#        [1.93840278e-13],
#        [9.99037564e-01],
#        [9.99732614e-01],
#        [1.12400383e-01],
#        [6.27967855e-03],
#        [1.00000000e+00],
#        [1.74651471e-09],
#        [4.86811700e-07],
#        [3.99940536e-17],
#        [5.21390319e-01],
#        [3.30036892e-05],
#        [2.51563657e-02],
#        [9.99999940e-01],
#        [8.42063665e-01],
#        [1.00000000e+00],
#        [2.06361346e-05],
#        [2.91120321e-01],
#        [1.26737162e-01],
#        [9.99997675e-01],
#        [9.99685585e-01],
#        [1.00000000e+00],
#        [1.04642117e-04],
#        [8.08590797e-14],
#        [9.09634471e-01],
#        [1.26581581e-05],
#        [9.99965966e-01],
#        [1.00000000e+00],
#        [9.23070192e-01],
#        [1.00000000e+00],
#        [9.99999702e-01],
#        [9.89761293e-01],
#        [1.14011520e-03],
#        [8.61530423e-01],
#        [2.86584168e-06],
#        [2.10909992e-08],
#        [5.57080398e-07],
#        [9.99976575e-01],
#        [3.52968499e-07],
#        [3.97290230e-01],
#        [7.59410262e-01],
#        [2.52386332e-01],
#        [2.68838667e-05],
#        [9.99999940e-01],
#        [1.00000000e+00],
#        [3.39124391e-08],
#        [8.12744141e-01],
#        [3.13476143e-08],
#        [7.89664423e-09],
#        [9.99999285e-01],
#        [3.45739682e-04],
#        [7.82556757e-02],
#        [1.00000000e+00],
#        [1.00000000e+00],
#        [9.99918044e-01],
#        [1.34883313e-08],
#        [1.00000000e+00],
#        [8.79347266e-04],
#        [9.91272569e-01],
#        [1.00000000e+00],
#        [9.90696549e-01],
#        [6.15472686e-08],
#        [7.56763541e-10],
#        [6.79552674e-01],
#        [1.00000000e+00],
#        [1.00000000e+00],
#        [2.88833777e-04],
#        [1.68826318e-05],
#        [2.77509424e-03],
#        [9.48991299e-01],
#        [9.99999881e-01],
#        [1.61377564e-01],
#        [4.48485415e-11],
#        [2.27344510e-12],
#        [2.39570603e-08],
#        [1.00000000e+00],
#        [9.99999464e-01],
#        [1.38681168e-15],
#        [5.33735156e-01],
#        [9.99970138e-01],
#        [1.49255354e-14],
#        [9.74472836e-10],
#        [8.41978937e-02],
#        [1.00000000e+00],
#        [1.00000000e+00],
#        [9.95132148e-01],
#        [2.23413699e-05],
#        [1.42201572e-03],
#        [1.90642727e-12],
#        [5.99502710e-06],
#        [1.40248014e-14],
#        [1.00000000e+00],
#        [9.99999881e-01],
#        [2.77732543e-05],
#        [9.98658955e-01],
#        [5.15639840e-06],
#        [4.22384801e-11],
#        [9.99991834e-01],
#        [9.99940932e-01],
#        [9.99998331e-01],
#        [2.63790309e-04],
#        [2.98719466e-01],
#        [3.53601053e-14],
#        [7.35506192e-02],
#        [5.90796828e-01],
#        [9.99999702e-01],
#        [9.03248906e-01],
#        [1.00000000e+00],
#        [7.54230200e-07],
#        [1.51697255e-03],
#        [3.32605268e-04],
#        [9.99963105e-01],
#        [1.42635807e-01],
#        [9.99990165e-01],
#        [1.00000000e+00],
#        [7.14199143e-12],
#        [1.48159762e-09],
#        [1.10511732e-10],
#        [1.40225166e-04],
#        [3.58507846e-09],
#        [1.52993426e-02],
#        [9.97423112e-01],
#        [1.00000000e+00],
#        [9.99996245e-01],
#        [1.16463661e-01],
#        [1.00000000e+00],
#        [3.69027928e-02],
#        [9.99996722e-01],
#        [5.86923063e-02],
#        [4.12023276e-01],
#        [5.66493161e-03],
#        [5.54035395e-09],
#        [2.80376544e-09],
#        [1.10206362e-04],
#        [3.81470744e-10],
#        [9.97601151e-01],
#        [9.99997497e-01],
#        [9.99837697e-01],
#        [1.00000000e+00],
#        [9.99961436e-01],
#        [3.88420284e-01],
#        [1.99095890e-14],
#        [9.99999881e-01],
#        [9.99879658e-01],
#        [1.15725631e-02],
#        [1.00000000e+00],
#        [3.02392127e-18],
#        [4.18180227e-02],
#        [1.00000000e+00],
#        [9.99996603e-01],
#        [1.89500162e-03],
#        [6.95222497e-01],
#        [9.91702557e-01],
#        [9.95012581e-01],
#        [3.92405077e-08],
#        [9.63056895e-15],
#        [6.33815583e-03],
#        [1.21747729e-12],
#        [3.85136555e-05],
#        [6.98715382e-07],
#        [1.85619811e-07],
#        [1.84682765e-04],
#        [2.66711486e-05],
#        [3.12596143e-07],
#        [9.99969840e-01],
#        [9.99998569e-01],
#        [1.74533222e-02],
#        [8.90939593e-01],
#        [9.99844909e-01],
#        [1.00000000e+00],
#        [5.28495079e-08],
#        [8.53159308e-01]], dtype=float32)

# %%
# 예측 수행
pred = model_d.predict(gen_test, steps=10, verbose=0)
print(pred.shape)
pred
# Out:
# (296, 1)
# array([[1.0000000e+00],
#        [1.0000000e+00],
#        [7.5048506e-01],
#        [9.9999005e-01],
#        [9.9967879e-01],
#        [1.0000000e+00],
#        [2.7818975e-01],
#        [9.9999839e-01],
#        [9.9999851e-01],
#        [7.7861589e-01],
#        [7.8066860e-09],
#        [2.8732017e-02],
#        [2.8463253e-03],
#        [7.2139912e-08],
#        [1.4672979e-02],
#        [4.5767642e-06],
#        [2.2106569e-01],
#        [1.2141890e-01],
#        [1.0000000e+00],
#        [2.4208879e-07],
#        [1.0000000e+00],
#        [1.7280119e-07],
#        [1.0493755e-05],
#        [6.5118689e-07],
#        [1.9908734e-06],
#        [2.3678271e-02],
#        [2.5156476e-07],
#        [1.8956232e-01],
#        [7.0041329e-01],
#        [9.9870068e-01],
#        [2.9108027e-05],
#        [9.9999994e-01],
#        [5.6163234e-12],
#        [5.3636835e-08],
#        [9.9780512e-01],
#        [9.9999994e-01],
#        [6.9220340e-01],
#        [4.5894641e-01],
#        [2.2096488e-05],
#        [9.0396829e-11],
#        [1.0000000e+00],
#        [3.5743571e-03],
#        [1.5615383e-02],
#        [1.4058756e-11],
#        [1.0000000e+00],
#        [1.0000000e+00],
#        [3.0905712e-01],
#        [1.3808569e-01],
#        [5.9523553e-11],
#        [8.3168805e-09],
#        [1.3786386e-07],
#        [3.7001279e-14],
#        [6.3033823e-17],
#        [1.6281725e-06],
#        [1.0000000e+00],
#        [9.9999046e-01],
#        [9.9945211e-01],
#        [1.4480299e-04],
#        [5.2221140e-12],
#        [7.7156162e-01],
#        [9.1752756e-01],
#        [6.5709322e-12],
#        [8.9963388e-01],
#        [9.9999720e-01],
#        [9.2930758e-01],
#        [9.9960351e-01],
#        [9.9999255e-01],
#        [5.6449841e-03],
#        [6.2858885e-10],
#        [1.0000000e+00],
#        [9.9999690e-01],
#        [5.3760895e-11],
#        [9.5397478e-01],
#        [6.0354206e-15],
#        [2.5896144e-01],
#        [9.9953157e-01],
#        [9.9999899e-01],
#        [9.8070788e-01],
#        [9.9871629e-01],
#        [9.9944794e-01],
#        [9.5372689e-11],
#        [9.9774081e-01],
#        [9.9999511e-01],
#        [9.9766809e-01],
#        [9.9997956e-01],
#        [6.9415724e-01],
#        [8.9519441e-01],
#        [3.4035391e-03],
#        [1.0000000e+00],
#        [7.0163695e-04],
#        [2.7823061e-04],
#        [9.9979740e-01],
#        [9.9562562e-01],
#        [1.0000000e+00],
#        [1.0000000e+00],
#        [8.1164192e-04],
#        [5.4334046e-04],
#        [4.1665888e-01],
#        [9.9875444e-01],
#        [6.4431294e-11],
#        [1.0000000e+00],
#        [1.0000000e+00],
#        [7.6904729e-02],
#        [9.9985057e-01],
#        [3.1684298e-08],
#        [1.8049966e-12],
#        [9.9379444e-01],
#        [9.9999905e-01],
#        [8.3605748e-08],
#        [3.3694720e-01],
#        [1.1044582e-13],
#        [1.5390758e-09],
#        [1.0000000e+00],
#        [9.9999994e-01],
#        [4.5045032e-05],
#        [9.9999964e-01],
#        [6.6235806e-12],
#        [9.9999398e-01],
#        [9.3287975e-03],
#        [9.9717385e-01],
#        [9.9999845e-01],
#        [4.7675991e-17],
#        [4.6189913e-11],
#        [4.3601371e-08],
#        [9.8876929e-01],
#        [1.3488892e-06],
#        [9.9986565e-01],
#        [3.3352944e-08],
#        [1.0000000e+00],
#        [4.5706571e-08],
#        [9.9210930e-01],
#        [9.9998009e-01],
#        [1.0497486e-09],
#        [2.8242607e-04],
#        [1.0769541e-05],
#        [3.1428954e-07],
#        [4.8119422e-02],
#        [9.9999940e-01],
#        [1.0000000e+00],
#        [9.9985510e-01],
#        [3.8683370e-16],
#        [9.9999988e-01],
#        [4.1709836e-08],
#        [5.1188418e-09],
#        [1.0000000e+00],
#        [1.7057640e-05],
#        [9.9999475e-01],
#        [1.2122079e-16],
#        [9.9999744e-01],
#        [3.6337535e-06],
#        [1.9433478e-02],
#        [2.8980929e-01],
#        [9.9050297e-08],
#        [1.0000000e+00],
#        [9.3414565e-05],
#        [9.9739474e-11],
#        [1.3050125e-03],
#        [6.9484400e-07],
#        [8.7174348e-04],
#        [1.4837214e-09],
#        [7.8412064e-08],
#        [2.0084818e-07],
#        [3.4705256e-04],
#        [1.7401349e-05],
#        [9.9781471e-01],
#        [1.0000000e+00],
#        [1.0000000e+00],
#        [9.7357994e-01],
#        [8.9395627e-08],
#        [1.0000000e+00],
#        [4.3328972e-11],
#        [1.0000000e+00],
#        [4.6446975e-03],
#        [1.0000000e+00],
#        [2.0879143e-05],
#        [1.7913040e-06],
#        [9.9993759e-01],
#        [7.0560047e-14],
#        [1.1083673e-08],
#        [2.8137137e-09],
#        [4.0802762e-01],
#        [9.9841720e-01],
#        [9.9960256e-01],
#        [3.4825664e-06],
#        [4.6499076e-09],
#        [1.0000000e+00],
#        [9.9376243e-01],
#        [9.4592134e-03],
#        [1.7524747e-02],
#        [2.3286618e-01],
#        [9.9999988e-01],
#        [1.0000000e+00],
#        [5.8599782e-01],
#        [7.3935080e-01],
#        [1.0000000e+00],
#        [9.9876595e-01],
#        [1.0000000e+00],
#        [1.8917337e-04],
#        [2.1306027e-15],
#        [2.7151777e-06],
#        [9.0765320e-03],
#        [1.3387543e-07],
#        [4.1411000e-05],
#        [2.8264956e-06],
#        [1.0000000e+00],
#        [4.2688183e-04],
#        [9.9893099e-01],
#        [5.9041358e-09],
#        [8.8559249e-09],
#        [2.3035252e-06],
#        [8.2454461e-01],
#        [3.8173919e-11],
#        [9.9999851e-01],
#        [5.6327236e-01],
#        [1.0000000e+00],
#        [3.8962571e-05],
#        [9.4079439e-11],
#        [4.8412136e-07],
#        [3.5447726e-01],
#        [1.0000000e+00],
#        [2.9930710e-08],
#        [2.1432006e-05],
#        [1.2621596e-02],
#        [9.9935734e-01],
#        [2.1884800e-04],
#        [7.3589166e-05],
#        [9.9533284e-01],
#        [8.1122314e-10],
#        [9.9999970e-01],
#        [1.3786125e-11],
#        [9.3207771e-01],
#        [6.4701330e-12],
#        [3.6229394e-02],
#        [9.9994409e-01],
#        [4.4125274e-05],
#        [9.9795306e-01],
#        [7.4590290e-01],
#        [3.8147640e-01],
#        [8.7240785e-02],
#        [9.9839377e-01],
#        [1.1461071e-06],
#        [4.9742939e-05],
#        [3.1731482e-11],
#        [1.1394036e-04],
#        [1.5921237e-02],
#        [1.5230518e-10],
#        [9.9990332e-01],
#        [1.0000000e+00],
#        [9.9999881e-01],
#        [1.0000000e+00],
#        [9.9482932e-06],
#        [9.9973446e-01],
#        [2.3047949e-05],
#        [1.0819125e-01],
#        [9.9995577e-01],
#        [1.0000000e+00],
#        [1.6548752e-14],
#        [1.2767749e-01],
#        [9.9607259e-01],
#        [1.0000000e+00],
#        [6.3791021e-15],
#        [6.1431932e-10],
#        [9.9999982e-01],
#        [9.9983376e-01],
#        [4.7542994e-08],
#        [1.0000000e+00],
#        [9.9999392e-01],
#        [1.1385326e-05],
#        [1.9578440e-03],
#        [9.9999893e-01],
#        [6.8472719e-01],
#        [3.3911294e-06],
#        [8.1120352e-06],
#        [1.6834818e-05],
#        [4.4470278e-07],
#        [9.9999970e-01],
#        [1.0000000e+00],
#        [1.0000000e+00],
#        [9.9997705e-01],
#        [6.7180898e-03],
#        [2.6500665e-11],
#        [1.0000000e+00],
#        [9.9875236e-01],
#        [5.1456439e-09],
#        [9.9992794e-01],
#        [9.5233142e-01],
#        [2.3543841e-08],
#        [9.9999923e-01],
#        [9.9998331e-01],
#        [9.9544203e-01],
#        [9.9998957e-01],
#        [9.9937290e-01],
#        [9.9994826e-01],
#        [2.5962220e-04],
#        [7.8743427e-12],
#        [9.9998999e-01]], dtype=float32)

# %%
pred
